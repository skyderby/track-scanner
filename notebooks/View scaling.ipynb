# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

import pandas
from sklearn import preprocessing

df = pandas.read_csv('../data/test/#7990 15-56-18.CSV')

df['h_speed'] = (df['velN']**2 + df['velE']**2) ** 0.5 * 3.6
df['v_speed'] = df['velD'] * 3.6

df = raw_df.copy()[3441:]
X = df[['h_speed', 'v_speed']]
df[['h_speed', 'v_speed']] = preprocessing.scale(X)

plt.figure()
plt.plot(df['h_speed'], linewidth=0.5)
plt.plot(df['v_speed'], linewidth=0.5)


plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
